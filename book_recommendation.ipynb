# %% [markdown]
# # BOOK RECOMMENDER SYSTEM

# %% [markdown]
# ## Introduction

# %% [markdown]
# This project focuses on demonstrating a collaborative-filtering recommendation system.
#
# The dataset is taken from __[Goodreads Datasets](https://sites.google.com/eng.ucsd.edu/ucsdbookgraph/home)__, which contains three group of datasets:
# * meta-data of the books
# * user-book interactions
# * users' detailed book reviews
#
# However, this project only use **meta-data** and **user-book interactions** in order to build a book collaborative-filtering recommender system and we mainly focus on the **Comics & Graphic Genres** because the original dataset is too large (with over 2M books and 228M interactions)

# %% [markdown]
# ## Implementation

# %% [markdown]
# We work on these 2 datasets but the given format is *.gz*
# * goodreads_books_comics_graphic.json.gz (89,411 books)
# * goodreads_interactions_comics_graphic.json.gz (7,347,630 interactions)
#
# For simplicity, I've already parse both json file into csv file and only take the important field
#
# For book metadata, I parse it into *titles.csv* with below fields:
# * *title*: title of the book
# * *book_id*: unique id of a book
# * *ratings* : number of ratings
# * *url* : goodreads url of the book
# * *cover_image*: image url of the book
#
# For interaction, I parse it into *interactions.csv* with below fields:
# * *user_id*: unique id of a user
# * *book_id*: unique id of a book
# * *rating* : rating that a user give a book
#
# and because *interactions.csv* is quite large (315MB) so you can download it __[here](https://drive.google.com/file/d/1fey5xMQkP4k2bbPVpwn0DeQqx5CZpxZM/view?usp=sharing)__

# %% [markdown]
# ### Part I

# %%
import gzip
import json

# %%
import pandas as pd
titles = pd.read_csv('titles.csv')
titles["ratings"] = pd.to_numeric(titles["ratings"])

# %%
titles.head(5)
# Out:
#     book_id                                              title  ratings  \
# 0  30128855                                            Cruelle       16
# 1  13571772  Captain America: Winter Soldier (The Ultimate ...       51
# 2    707611                          Superman Archives, Vol. 2       51
# 3   2250580                            A.I. Revolution, Vol. 1       46
# 4  27036536                              War Stories, Volume 3       39
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/30128855-c...
# 1  https://www.goodreads.com/book/show/13571772-c...
# 2  https://www.goodreads.com/book/show/707611.Sup...
# 3  https://www.goodreads.com/book/show/2250580.A_...
# 4  https://www.goodreads.com/book/show/27036536-w...
#
#                                          cover_image
# 0  https://images.gr-assets.com/books/1462644346m...
# 1  https://images.gr-assets.com/books/1333287305m...
# 2  https://images.gr-assets.com/books/1307838888m...
# 3  https://s.gr-assets.com/assets/nophoto/book/11...
# 4  https://images.gr-assets.com/books/1445402463m...

# %% [markdown]
# Process title and create *mod_title* so that we can query a book by its name. In this step, we basically keep only normal characters and strip the unncessary whitespace

# %%
import re

def process_title(title):
    mod_title = re.sub("[^a-zA-Z0-9 ]", "", title)
    mod_title = mod_title.lower()
    mod_title = re.sub("\s+", " ", mod_title)
    return mod_title

# %%
titles["mod_title"] = titles["title"].apply(process_title)
titles = titles[titles["mod_title"].str.len() > 0]

# %%
titles.head(5)
# Out:
#     book_id                                              title  ratings  \
# 0  30128855                                            Cruelle       16
# 1  13571772  Captain America: Winter Soldier (The Ultimate ...       51
# 2    707611                          Superman Archives, Vol. 2       51
# 3   2250580                            A.I. Revolution, Vol. 1       46
# 4  27036536                              War Stories, Volume 3       39
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/30128855-c...
# 1  https://www.goodreads.com/book/show/13571772-c...
# 2  https://www.goodreads.com/book/show/707611.Sup...
# 3  https://www.goodreads.com/book/show/2250580.A_...
# 4  https://www.goodreads.com/book/show/27036536-w...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1462644346m...
# 1  https://images.gr-assets.com/books/1333287305m...
# 2  https://images.gr-assets.com/books/1307838888m...
# 3  https://s.gr-assets.com/assets/nophoto/book/11...
# 4  https://images.gr-assets.com/books/1445402463m...
#
#                                            mod_title
# 0                                            cruelle
# 1  captain america winter soldier the ultimate gr...
# 2                            superman archives vol 2
# 3                                ai revolution vol 1
# 4                               war stories volume 3

# %% [markdown]
# Vectorize each *mod_title* using TF-IDF and find the most similar title with the given book name. We find the similarity by using *cosine_similarity*

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()

tfidf_mat = tfidf_vectorizer.fit_transform(titles["mod_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def make_clickable(val):
    return '<a target= "_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

def search_book(query, tfidf_vectorizer):
    processed_q = process_title(query)
    query_vec = tfidf_vectorizer.transform([processed_q])
    similarity = cosine_similarity(query_vec,tfidf_mat).flatten()

    indices = np.argpartition(similarity, -10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    return results.head(5).style.format({'url': make_clickable, 'cover_image':show_image})

# %%
search_book('Superman', tfidf_vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_20b02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20b02_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_20b02_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_20b02_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_20b02_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_20b02_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_20b02_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20b02_level0_row0" class="row_heading level0 row0" >53582</th>
#       <td id="T_20b02_row0_col0" class="data row0 col0" >19993681</td>
#       <td id="T_20b02_row0_col1" class="data row0 col1" >Superman #1</td>
#       <td id="T_20b02_row0_col2" class="data row0 col2" >336</td>
#       <td id="T_20b02_row0_col3" class="data row0 col3" ><a target= "_blank" href="https://www.goodreads.com/book/show/19993681-superman-1">Goodreads</a></td>
#       <td id="T_20b02_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1508878107m/19993681.jpg" width=50></img></td>
#       <td id="T_20b02_row0_col5" class="data row0 col5" >superman 1</td>
#     </tr>
#     <tr>
#       <th id="T_20b02_level0_row1" class="row_heading level0 row1" >20859</th>
#       <td id="T_20b02_row1_col0" class="data row1 col0" >19738768</td>
#       <td id="T_20b02_row1_col1" class="data row1 col1" >Superman #2</td>
#       <td id="T_20b02_row1_col2" class="data row1 col2" >108</td>
#       <td id="T_20b02_row1_col3" class="data row1 col3" ><a target= "_blank" href="https://www.goodreads.com/book/show/19738768-superman-2">Goodreads</a></td>
#       <td id="T_20b02_row1_col4" class="data row1 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_20b02_row1_col5" class="data row1 col5" >superman 2</td>
#     </tr>
#     <tr>
#       <th id="T_20b02_level0_row2" class="row_heading level0 row2" >32364</th>
#       <td id="T_20b02_row2_col0" class="data row2 col0" >19749416</td>
#       <td id="T_20b02_row2_col1" class="data row2 col1" >Superman #3</td>
#       <td id="T_20b02_row2_col2" class="data row2 col2" >79</td>
#       <td id="T_20b02_row2_col3" class="data row2 col3" ><a target= "_blank" href="https://www.goodreads.com/book/show/19749416-superman-3">Goodreads</a></td>
#       <td id="T_20b02_row2_col4" class="data row2 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_20b02_row2_col5" class="data row2 col5" >superman 3</td>
#     </tr>
#     <tr>
#       <th id="T_20b02_level0_row3" class="row_heading level0 row3" >16936</th>
#       <td id="T_20b02_row3_col0" class="data row3 col0" >20101276</td>
#       <td id="T_20b02_row3_col1" class="data row3 col1" >Superman #6</td>
#       <td id="T_20b02_row3_col2" class="data row3 col2" >63</td>
#       <td id="T_20b02_row3_col3" class="data row3 col3" ><a target= "_blank" href="https://www.goodreads.com/book/show/20101276-superman-6">Goodreads</a></td>
#       <td id="T_20b02_row3_col4" class="data row3 col4" ><img src="https://images.gr-assets.com/books/1508878704m/20101276.jpg" width=50></img></td>
#       <td id="T_20b02_row3_col5" class="data row3 col5" >superman 6</td>
#     </tr>
#     <tr>
#       <th id="T_20b02_level0_row4" class="row_heading level0 row4" >16378</th>
#       <td id="T_20b02_row4_col0" class="data row4 col0" >19652558</td>
#       <td id="T_20b02_row4_col1" class="data row4 col1" >Superman #5</td>
#       <td id="T_20b02_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_20b02_row4_col3" class="data row4 col3" ><a target= "_blank" href="https://www.goodreads.com/book/show/19652558-superman-5">Goodreads</a></td>
#       <td id="T_20b02_row4_col4" class="data row4 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_20b02_row4_col5" class="data row4 col5" >superman 5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Simulate a list of favorite books so we can perform some recommendation based on these books

# %%
liked_books = ["1237398", "364950", "364958", "364954", "1532905"]

# %%
interactions = pd.read_csv('interactions.csv')
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
interactions
# Out:
#                                   user_id   book_id  rating
# 0        8842281e1d1347389f2ab93d60773d4d    836610       0
# 1        8842281e1d1347389f2ab93d60773d4d   7648967       0
# 2        8842281e1d1347389f2ab93d60773d4d  15704307       0
# 3        8842281e1d1347389f2ab93d60773d4d   6902644       0
# 4        8842281e1d1347389f2ab93d60773d4d   9844623       0
# ...                                   ...       ...     ...
# 7347625  bd3ac2e547a4f521927056cbd6bb5c2f   1484167       5
# 7347626  bd3ac2e547a4f521927056cbd6bb5c2f    122451       5
# 7347627  6384a10d5611945b26b25c971f348fa4     85574       3
# 7347628  e9aea57d21cdf9d91a65687d59518924     15197       5
# 7347629  762121298ddd3820c9477c6f03f145ab   6493321       4
#
# [7347630 rows x 3 columns]

# %% [markdown]
# Find the list of user who like the same book

# %%
#find overlap interaction, this is interaction of user who like book in our favorite book list
overlap_interactions = interactions[interactions["book_id"].isin(liked_books)]
overlap_interactions = overlap_interactions[overlap_interactions["rating"] >= 3]
overlap_interactions
# Out:
#                                   user_id  book_id  rating
# 3611     6b5ffddfaca8dec2049e0bb0e2d6edf6   364958       5
# 3613     6b5ffddfaca8dec2049e0bb0e2d6edf6   364954       3
# 3615     6b5ffddfaca8dec2049e0bb0e2d6edf6   364950       3
# 3620     6b5ffddfaca8dec2049e0bb0e2d6edf6  1237398       5
# 3711     3cd7e962765c795dea97babd41215e99  1237398       5
# ...                                   ...      ...     ...
# 7346805  5a2154b4a0df45dcc946dbc6db4fa215  1237398       3
# 7347086  6fb7a4172710f1d8bcdc658a302450dc  1237398       5
# 7347377  1b51feff1cb53697b11e97ebf65e5595  1237398       4
# 7347535  0b7de731a1d5bfe06bc4d8e2939c1b94   364958       5
# 7347547  0b7de731a1d5bfe06bc4d8e2939c1b94  1237398       5
#
# [5168 rows x 3 columns]

# %%
overlap_users = overlap_interactions["user_id"].unique()
overlap_users
# Out:
# array(['6b5ffddfaca8dec2049e0bb0e2d6edf6',
#        '3cd7e962765c795dea97babd41215e99',
#        'e6d35f5d6eed3b8981a224d43c24f2b7', ...,
#        '6fb7a4172710f1d8bcdc658a302450dc',
#        '1b51feff1cb53697b11e97ebf65e5595',
#        '0b7de731a1d5bfe06bc4d8e2939c1b94'], dtype=object)

# %% [markdown]
# In part I, we gonna use a basic intuitive approach to provide books recommendation:
#
# * Get list of user who also like the same book in the favorite list
# * Get all the books that the above list of user rated
# * Count number of appearance of each book
# * Calculate the popularity score of each book, make sure that the recommender don't just always recommend the most rated books
# * Produce the recommendation based on popularity score

# %%
rec_books = interactions[interactions["user_id"].isin(overlap_users)]
# get list of book that common user also rated

# %%
import pandas as pd

recs = pd.DataFrame(rec_books, columns = ["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)
recs
# Out:
#                                   user_id   book_id  rating
# 3510     6b5ffddfaca8dec2049e0bb0e2d6edf6  33583817       3
# 3511     6b5ffddfaca8dec2049e0bb0e2d6edf6    431274       5
# 3512     6b5ffddfaca8dec2049e0bb0e2d6edf6  32473025       4
# 3513     6b5ffddfaca8dec2049e0bb0e2d6edf6  17671951       4
# 3514     6b5ffddfaca8dec2049e0bb0e2d6edf6  31140467       3
# ...                                   ...       ...     ...
# 7347548  0b7de731a1d5bfe06bc4d8e2939c1b94    330744       4
# 7347549  0b7de731a1d5bfe06bc4d8e2939c1b94   3173558       5
# 7347550  0b7de731a1d5bfe06bc4d8e2939c1b94    204042       5
# 7347551  0b7de731a1d5bfe06bc4d8e2939c1b94      2880       5
# 7347552  0b7de731a1d5bfe06bc4d8e2939c1b94     13615       5
#
# [576919 rows x 3 columns]

# %%
# recs.to_csv("recommendation.csv", index=False)

# %%
top_recs = recs["book_id"].value_counts()
top_books = top_recs.index.values
top_books
# Out:
# array(['1237398', '2880', '204042', ..., '16002104', '598642', '1792672'],
#       dtype=object)

# %%
books_titles = titles
books_titles["book_id"] = books_titles["book_id"].astype(str)
books_titles
# Out:
#         book_id                                              title  ratings  \
# 0      30128855                                            Cruelle       16
# 1      13571772  Captain America: Winter Soldier (The Ultimate ...       51
# 2        707611                          Superman Archives, Vol. 2       51
# 3       2250580                            A.I. Revolution, Vol. 1       46
# 4      27036536                              War Stories, Volume 3       39
# ...         ...                                                ...      ...
# 63678   3106983  Persepolis: The Story of a Childhood and The S...     1966
# 63679  10644600                                        Fevre Dream      853
# 63680  22746413                                 Blood Lad, Vol. 10       66
# 63681  30848889               Doctor Who: Free Comic Book Day 2016      338
# 63682  20653416                  La búsqueda del pájaro del tiempo       28
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/30128855-c...
# 1      https://www.goodreads.com/book/show/13571772-c...
# 2      https://www.goodreads.com/book/show/707611.Sup...
# 3      https://www.goodreads.com/book/show/2250580.A_...
# 4      https://www.goodreads.com/book/show/27036536-w...
# ...                                                  ...
# 63678  https://www.goodreads.com/book/show/3106983-pe...
# 63679  https://www.goodreads.com/book/show/10644600-f...
# 63680  https://www.goodreads.com/book/show/22746413-b...
# 63681  https://www.goodreads.com/book/show/30848889-d...
# 63682  https://www.goodreads.com/book/show/20653416-l...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1462644346m...
# 1      https://images.gr-assets.com/books/1333287305m...
# 2      https://images.gr-assets.com/books/1307838888m...
# 3      https://s.gr-assets.com/assets/nophoto/book/11...
# 4      https://images.gr-assets.com/books/1445402463m...
# ...                                                  ...
# 63678  https://images.gr-assets.com/books/1466547436m...
# 63679  https://images.gr-assets.com/books/1350850473m...
# 63680  https://images.gr-assets.com/books/1405832210m...
# 63681  https://s.gr-assets.com/assets/nophoto/book/11...
# 63682  https://images.gr-assets.com/books/1391037254m...
#
#                                                mod_title
# 0                                                cruelle
# 1      captain america winter soldier the ultimate gr...
# 2                                superman archives vol 2
# 3                                    ai revolution vol 1
# 4                                   war stories volume 3
# ...                                                  ...
# 63678  persepolis the story of a childhood and the st...
# 63679                                        fevre dream
# 63680                                   blood lad vol 10
# 63681                doctor who free comic book day 2016
# 63682                    la bsqueda del pjaro del tiempo
#
# [63618 rows x 6 columns]

# %%
all_recs = recs["book_id"].value_counts()
all_recs = all_recs.to_frame().reset_index()
all_recs.rename(columns={"index":"book_id", "book_id":"book_count"}, inplace= True)
all_recs
#book_count denotes number of apperance
# Out:
#         book_id  book_count
# 0       1237398        3322
# 1          2880        1843
# 2        204042        1825
# 3         13615        1681
# 4           870        1577
# ...         ...         ...
# 47512   2020926           1
# 47513  24612648           1
# 47514  16002104           1
# 47515    598642           1
# 47516   1792672           1
#
# [47517 rows x 2 columns]

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")
all_recs
# Out:
#         book_id  book_count  \
# 0       1237398        3322
# 1          2880        1843
# 2        204042        1825
# 3         13615        1681
# 4           870        1577
# ...         ...         ...
# 43370   7575742           1
# 43371  24612648           1
# 43372  16002104           1
# 43373    598642           1
# 43374   1792672           1
#
#                                                    title  ratings  \
# 0      One Piece, Volume 01: Romance Dawn (One Piece,...    69279
# 1                                      Bleach, Volume 01   123807
# 2      Naruto, Vol. 01: The Tests of the Ninja (Narut...   107910
# 3           Death Note, Vol. 1: Boredom (Death Note, #1)   142755
# 4      Fullmetal Alchemist, Vol. 1 (Fullmetal Alchemi...    95704
# ...                                                  ...      ...
# 43370                       Superman: New Krypton Vol. 1       48
# 43371                           Slappy's Tales of Horror       22
# 43372                              Civil War Prose Novel      159
# 43373                    The Darkness Compendium, Vol. 1      124
# 43374          Sailor Moon, tome 11: La Princesse Kaguya       21
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/1237398.On...
# 1      https://www.goodreads.com/book/show/2880.Bleac...
# 2      https://www.goodreads.com/book/show/204042.Nar...
# 3      https://www.goodreads.com/book/show/13615.Deat...
# 4      https://www.goodreads.com/book/show/870.Fullme...
# ...                                                  ...
# 43370  https://www.goodreads.com/book/show/7575742-su...
# 43371  https://www.goodreads.com/book/show/24612648-s...
# 43372  https://www.goodreads.com/book/show/16002104-c...
# 43373  https://www.goodreads.com/book/show/598642.The...
# 43374  https://www.goodreads.com/book/show/1792672.Sa...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1318523719m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://images.gr-assets.com/books/1435524806m...
# 3      https://images.gr-assets.com/books/1419952134m...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 43370  https://images.gr-assets.com/books/1308167673m...
# 43371  https://images.gr-assets.com/books/1423543969m...
# 43372  https://images.gr-assets.com/books/1360567098m...
# 43373  https://images.gr-assets.com/books/1333278478m...
# 43374  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                              mod_title
# 0         one piece volume 01 romance dawn one piece 1
# 1                                     bleach volume 01
# 2        naruto vol 01 the tests of the ninja naruto 1
# 3                death note vol 1 boredom death note 1
# 4      fullmetal alchemist vol 1 fullmetal alchemist 1
# ...                                                ...
# 43370                       superman new krypton vol 1
# 43371                          slappys tales of horror
# 43372                            civil war prose novel
# 43373                    the darkness compendium vol 1
# 43374          sailor moon tome 11 la princesse kaguya
#
# [43375 rows x 7 columns]

# %%
#calculate popularity score for each book, we ensure the one with high rating count will be less popular than usual
all_recs["score"] = all_recs.book_count * (all_recs.book_count / all_recs.ratings)

# %%
recommendation = all_recs.sort_values("score", ascending = False)

# %%
def make_clickable(val):
    return '<a target= "_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

recommendation[~recommendation["book_id"].isin(liked_books)].head(5).style.format({'url': make_clickable, 'cover_image':show_image})
#get the top-5 highest score excluding the book already in the favorite list
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f14b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f14b_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_2f14b_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_2f14b_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_2f14b_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_2f14b_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_2f14b_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_2f14b_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_2f14b_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f14b_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_2f14b_row0_col0" class="data row0 col0" >364956</td>
#       <td id="T_2f14b_row0_col1" class="data row0 col1" >899</td>
#       <td id="T_2f14b_row0_col2" class="data row0 col2" >One Piece, Volume 02: Buggy the Clown (One Piece, #2)</td>
#       <td id="T_2f14b_row0_col3" class="data row0 col3" >6512</td>
#       <td id="T_2f14b_row0_col4" class="data row0 col4" ><a target= "_blank" href="https://www.goodreads.com/book/show/364956.One_Piece_Volume_02">Goodreads</a></td>
#       <td id="T_2f14b_row0_col5" class="data row0 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2f14b_row0_col6" class="data row0 col6" >one piece volume 02 buggy the clown one piece 2</td>
#       <td id="T_2f14b_row0_col7" class="data row0 col7" >124.109490</td>
#     </tr>
#     <tr>
#       <th id="T_2f14b_level0_row1" class="row_heading level0 row1" >14</th>
#       <td id="T_2f14b_row1_col0" class="data row1 col0" >364957</td>
#       <td id="T_2f14b_row1_col1" class="data row1 col1" >782</td>
#       <td id="T_2f14b_row1_col2" class="data row1 col2" >One Piece, Volume 03: Don't Get Fooled Again (One Piece, #3)</td>
#       <td id="T_2f14b_row1_col3" class="data row1 col3" >5472</td>
#       <td id="T_2f14b_row1_col4" class="data row1 col4" ><a target= "_blank" href="https://www.goodreads.com/book/show/364957.One_Piece_Volume_03">Goodreads</a></td>
#       <td id="T_2f14b_row1_col5" class="data row1 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2f14b_row1_col6" class="data row1 col6" >one piece volume 03 dont get fooled again one piece 3</td>
#       <td id="T_2f14b_row1_col7" class="data row1 col7" >111.755117</td>
#     </tr>
#     <tr>
#       <th id="T_2f14b_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_2f14b_row2_col0" class="data row2 col0" >364952</td>
#       <td id="T_2f14b_row2_col1" class="data row2 col1" >727</td>
#       <td id="T_2f14b_row2_col2" class="data row2 col2" >One Piece, Volume 04: The Black Cat Pirates (One Piece, #4)</td>
#       <td id="T_2f14b_row2_col3" class="data row2 col3" >5422</td>
#       <td id="T_2f14b_row2_col4" class="data row2 col4" ><a target= "_blank" href="https://www.goodreads.com/book/show/364952.One_Piece_Volume_04">Goodreads</a></td>
#       <td id="T_2f14b_row2_col5" class="data row2 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2f14b_row2_col6" class="data row2 col6" >one piece volume 04 the black cat pirates one piece 4</td>
#       <td id="T_2f14b_row2_col7" class="data row2 col7" >97.478606</td>
#     </tr>
#     <tr>
#       <th id="T_2f14b_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_2f14b_row3_col0" class="data row3 col0" >364951</td>
#       <td id="T_2f14b_row3_col1" class="data row3 col1" >679</td>
#       <td id="T_2f14b_row3_col2" class="data row3 col2" >One Piece, Volume 05: For Whom the Bell Tolls (One Piece, #5)</td>
#       <td id="T_2f14b_row3_col3" class="data row3 col3" >4919</td>
#       <td id="T_2f14b_row3_col4" class="data row3 col4" ><a target= "_blank" href="https://www.goodreads.com/book/show/364951.One_Piece_Volume_05">Goodreads</a></td>
#       <td id="T_2f14b_row3_col5" class="data row3 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2f14b_row3_col6" class="data row3 col6" >one piece volume 05 for whom the bell tolls one piece 5</td>
#       <td id="T_2f14b_row3_col7" class="data row3 col7" >93.726570</td>
#     </tr>
#     <tr>
#       <th id="T_2f14b_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_2f14b_row4_col0" class="data row4 col0" >364960</td>
#       <td id="T_2f14b_row4_col1" class="data row4 col1" >545</td>
#       <td id="T_2f14b_row4_col2" class="data row4 col2" >One Piece, Volume 10: OK, Let's Stand Up! (One Piece, #10)</td>
#       <td id="T_2f14b_row4_col3" class="data row4 col3" >3527</td>
#       <td id="T_2f14b_row4_col4" class="data row4 col4" ><a target= "_blank" href="https://www.goodreads.com/book/show/364960.One_Piece_Volume_10">Goodreads</a></td>
#       <td id="T_2f14b_row4_col5" class="data row4 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_2f14b_row4_col6" class="data row4 col6" >one piece volume 10 ok lets stand up one piece 10</td>
#       <td id="T_2f14b_row4_col7" class="data row4 col7" >84.214630</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Part II

# %% [markdown]
# In Part I, we use an intuitive approach which may not produce the best recommendations.
#
# In this part, we try to use another approach which find user who has the most similar taste to us using cosine_similarity and  take a look at which books the other users likes, then produce recommendations

# %%
# read the list of my rated books
my_books = pd.read_csv("goodreads_library_export.csv")
my_books["book_id"] = my_books["book_id"].astype(str)
my_books
# Out:
#      book_id                                              title  rating  \
# 0    6131591                                 Doraemon Buku Ke-2       5
# 1    1315744                ドラえもん 1 [Doraemon 1] (Doraemon, #1)       5
# 2    6131665                                 Doraemon Buku Ke-9       5
# 3    6131651                                 Doraemon Buku Ke-8       5
# 4    6131593                                 Doraemon Buku Ke-3       5
# ..       ...                                                ...     ...
# 71  18667307              Tokyo Ghoul, Tome 1 (Tokyo Ghoul, #1)       5
# 72  13154150      Attack on Titan, Vol. 1 (Attack on Titan, #1)       5
# 73       870  Fullmetal Alchemist, Vol. 1 (Fullmetal Alchemi...       5
# 74    969275  Dragon Ball, Vol. 1: The Monkey King (Dragon B...       5
# 75    204042        Naruto, Vol. 1: Uzumaki Naruto (Naruto, #1)       5
#
#     user_id
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
# ..      ...
# 71       -1
# 72       -1
# 73       -1
# 74       -1
# 75       -1
#
# [76 rows x 4 columns]

# %%
my_books_list = list(my_books["book_id"])

# %% [markdown]
# Find the user who has common interest

# %%
interactions = pd.read_csv('interactions.csv')
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])
interactions
# Out:
#                                   user_id   book_id  rating
# 0        8842281e1d1347389f2ab93d60773d4d    836610       0
# 1        8842281e1d1347389f2ab93d60773d4d   7648967       0
# 2        8842281e1d1347389f2ab93d60773d4d  15704307       0
# 3        8842281e1d1347389f2ab93d60773d4d   6902644       0
# 4        8842281e1d1347389f2ab93d60773d4d   9844623       0
# ...                                   ...       ...     ...
# 7347625  bd3ac2e547a4f521927056cbd6bb5c2f   1484167       5
# 7347626  bd3ac2e547a4f521927056cbd6bb5c2f    122451       5
# 7347627  6384a10d5611945b26b25c971f348fa4     85574       3
# 7347628  e9aea57d21cdf9d91a65687d59518924     15197       5
# 7347629  762121298ddd3820c9477c6f03f145ab   6493321       4
#
# [7347630 rows x 3 columns]

# %%
#find common interactions, which rated the same book in our favorite list
overlap_interactions = interactions[interactions["book_id"].isin(my_books_list)]
overlap_interactions
# Out:
#                                   user_id   book_id  rating
# 138      4035e5f05352217609c1a294410f2d50  13154150       4
# 139      4035e5f05352217609c1a294410f2d50  13531561       4
# 277      4980305f36ab8c2ab831e401a185f28a    204042       5
# 298      4980305f36ab8c2ab831e401a185f28a     13618       5
# 300      4980305f36ab8c2ab831e401a185f28a     13615       5
# ...                                   ...       ...     ...
# 7347535  0b7de731a1d5bfe06bc4d8e2939c1b94    364958       5
# 7347543  0b7de731a1d5bfe06bc4d8e2939c1b94    969275       4
# 7347547  0b7de731a1d5bfe06bc4d8e2939c1b94   1237398       5
# 7347550  0b7de731a1d5bfe06bc4d8e2939c1b94    204042       5
# 7347552  0b7de731a1d5bfe06bc4d8e2939c1b94     13615       5
#
# [86084 rows x 3 columns]

# %%
#find the user who rated the same books as ours and count number of rated books we have in common
overlap_users = overlap_interactions["user_id"].value_counts()
overlap_users = overlap_users.to_dict()

# %%
# only consider user who has rated more than 20% books compared to our list
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5])

# %%
interactions = interactions[interactions["user_id"].isin(filtered_overlap_users)]
interactions.reset_index()
interactions
# Out:
#                                   user_id   book_id  rating
# 3510     6b5ffddfaca8dec2049e0bb0e2d6edf6  33583817       3
# 3511     6b5ffddfaca8dec2049e0bb0e2d6edf6    431274       5
# 3512     6b5ffddfaca8dec2049e0bb0e2d6edf6  32473025       4
# 3513     6b5ffddfaca8dec2049e0bb0e2d6edf6  17671951       4
# 3514     6b5ffddfaca8dec2049e0bb0e2d6edf6  31140467       3
# ...                                   ...       ...     ...
# 7246898  a63a061afb8954263f57ebaaa9ac127e  13531561       0
# 7246899  a63a061afb8954263f57ebaaa9ac127e       870       0
# 7246900  a63a061afb8954263f57ebaaa9ac127e    204042       5
# 7246901  a63a061afb8954263f57ebaaa9ac127e  13154150       0
# 7246902  a63a061afb8954263f57ebaaa9ac127e  17694052       5
#
# [382552 rows x 3 columns]

# %%
interactions = pd.concat([my_books[['user_id','book_id', 'rating']], interactions])
interactions
# Out:
#                                   user_id   book_id  rating
# 0                                      -1   6131591       5
# 1                                      -1   1315744       5
# 2                                      -1   6131665       5
# 3                                      -1   6131651       5
# 4                                      -1   6131593       5
# ...                                   ...       ...     ...
# 7246898  a63a061afb8954263f57ebaaa9ac127e  13531561       0
# 7246899  a63a061afb8954263f57ebaaa9ac127e       870       0
# 7246900  a63a061afb8954263f57ebaaa9ac127e    204042       5
# 7246901  a63a061afb8954263f57ebaaa9ac127e  13154150       0
# 7246902  a63a061afb8954263f57ebaaa9ac127e  17694052       5
#
# [382628 rows x 3 columns]

# %%
#make sure it in the right type
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %% [markdown]
# Create Ultility Matrix

# %%
#indexing user and book so that we can create a ultility matrix to compare similarity between user
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))
ratings_mat = ratings_mat_coo.tocsr()

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
#take top 15 similar 
indices = np.argpartition(similarity, -15)[-15:]
indices
# Out:
# array([108, 248, 219, 280, 259, 591,  73, 511, 271, 598,  87, 358, 197,
#         64,   0], dtype=int64)

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()
similar_users = similar_users[similar_users["user_id"]  != "-1"]

# %%
similar_users
# Out:
#                                   user_id   book_id  rating  user_index  \
# 3510     6b5ffddfaca8dec2049e0bb0e2d6edf6  33583817       3         248
# 3511     6b5ffddfaca8dec2049e0bb0e2d6edf6    431274       5         248
# 3512     6b5ffddfaca8dec2049e0bb0e2d6edf6  32473025       4         248
# 3513     6b5ffddfaca8dec2049e0bb0e2d6edf6  17671951       4         248
# 3514     6b5ffddfaca8dec2049e0bb0e2d6edf6  31140467       3         248
# ...                                   ...       ...     ...         ...
# 6837357  61988e9ef5529df077c92ccf2cc0ce95  20504346       5         219
# 6837358  61988e9ef5529df077c92ccf2cc0ce95  22447402       3         219
# 6837359  61988e9ef5529df077c92ccf2cc0ce95  17835727       5         219
# 6837360  61988e9ef5529df077c92ccf2cc0ce95  17703205       4         219
# 6837361  61988e9ef5529df077c92ccf2cc0ce95  10710392       3         219
#
#          book_index
# 3510          29858
# 3511          31723
# 3512          28867
# 3513          11191
# 3514          27955
# ...             ...
# 6837357       15631
# 6837358       17790
# 6837359       11613
# 6837360       11300
# 6837361        1264
#
# [2095 rows x 5 columns]

# %%
book_recs = similar_users.groupby("book_id").rating.agg(["count", "mean"])

# %%
book_recs
# Out:
#           count  mean
# book_id
# 1000392       2   2.0
# 10088114      1   3.0
# 1011359       1   0.0
# 10138607      1   0.0
# 1015307       1   0.0
# ...         ...   ...
# 986056        1   5.0
# 986057        1   5.0
# 986061        1   4.0
# 9876989       1   5.0
# 991634        1   0.0
#
# [1167 rows x 2 columns]

# %%
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#        book_id  count  mean  \
# 0      1000392      2   2.0
# 1     10088114      1   3.0
# 2      1011359      1   0.0
# 3     10138607      1   0.0
# 4      1015307      1   0.0
# ...        ...    ...   ...
# 1158    986056      1   5.0
# 1159    986057      1   5.0
# 1160    986061      1   4.0
# 1161   9876989      1   5.0
# 1162    991634      1   0.0
#
#                                                   title  ratings  \
# 0                 Naruto, Vol. 16: Eulogy (Naruto, #16)     5837
# 1          Morning Glories, Vol. 1: For a Better Future     8263
# 2     Ouran High School Host Club, Vol. 2 (Ouran Hig...    14557
# 3                                                Habibi    28405
# 4                Negima!: Magister Negi Magi, Volume 12      635
# ...                                                 ...      ...
# 1158                     Video Girl Ai, Vol. 07: Retake      159
# 1159                   Video Girl Ai, Vol. 02: Mix Down      228
# 1160                   Video Girl Ai, Vol. 13: Fade Out      135
# 1161         Blue Exorcist, Vol. 1  (Blue Exorcist, #1)    40889
# 1162  Black: The Birth of Evil (The Circle: The Grap...      534
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/1000392.Na...
# 1     https://www.goodreads.com/book/show/10088114-m...
# 2     https://www.goodreads.com/book/show/1011359.Ou...
# 3     https://www.goodreads.com/book/show/10138607-h...
# 4     https://www.goodreads.com/book/show/1015307.Ne...
# ...                                                 ...
# 1158  https://www.goodreads.com/book/show/986056.Vid...
# 1159  https://www.goodreads.com/book/show/986057.Vid...
# 1160  https://www.goodreads.com/book/show/986061.Vid...
# 1161  https://www.goodreads.com/book/show/9876989-bl...
# 1162   https://www.goodreads.com/book/show/991634.Black
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1435525315m...
# 1     https://images.gr-assets.com/books/1486028570m...
# 2     https://s.gr-assets.com/assets/nophoto/book/11...
# 3     https://images.gr-assets.com/books/1327899014m...
# 4     https://images.gr-assets.com/books/1333577628m...
# ...                                                 ...
# 1158  https://images.gr-assets.com/books/1344400197m...
# 1159  https://s.gr-assets.com/assets/nophoto/book/11...
# 1160  https://s.gr-assets.com/assets/nophoto/book/11...
# 1161  https://images.gr-assets.com/books/1432642113m...
# 1162  https://images.gr-assets.com/books/1380857855m...
#
#                                               mod_title
# 0                        naruto vol 16 eulogy naruto 16
# 1             morning glories vol 1 for a better future
# 2     ouran high school host club vol 2 ouran high s...
# 3                                                habibi
# 4                   negima magister negi magi volume 12
# ...                                                 ...
# 1158                        video girl ai vol 07 retake
# 1159                      video girl ai vol 02 mix down
# 1160                      video girl ai vol 13 fade out
# 1161                blue exorcist vol 1 blue exorcist 1
# 1162  black the birth of evil the circle the graphic...
#
# [1163 rows x 8 columns]

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"] 

book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]
book_recs = book_recs[book_recs["count"] > 2]
book_recs = book_recs[book_recs["mean"] >= 3.5]

# %%
top_recs = book_recs.sort_values("score", ascending = False)

# %%
def make_clickable(val):
    return '<a target= "_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

top_recs.head(5).style.format({'url': make_clickable, 'cover_image':show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a309">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a309_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_3a309_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_3a309_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_3a309_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_3a309_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_3a309_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_3a309_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_3a309_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_3a309_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_3a309_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a309_level0_row0" class="row_heading level0 row0" >985</th>
#       <td id="T_3a309_row0_col0" class="data row0 col0" >6801644</td>
#       <td id="T_3a309_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_3a309_row0_col2" class="data row0 col2" >4.250000</td>
#       <td id="T_3a309_row0_col3" class="data row0 col3" >One Piece, Volume 31: We'll Be Here (One Piece, #31)</td>
#       <td id="T_3a309_row0_col4" class="data row0 col4" >227</td>
#       <td id="T_3a309_row0_col5" class="data row0 col5" ><a target= "_blank" href="https://www.goodreads.com/book/show/6801644-one-piece-volume-31">Goodreads</a></td>
#       <td id="T_3a309_row0_col6" class="data row0 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_3a309_row0_col7" class="data row0 col7" >one piece volume 31 well be here one piece 31</td>
#       <td id="T_3a309_row0_col8" class="data row0 col8" >0.281938</td>
#       <td id="T_3a309_row0_col9" class="data row0 col9" >1.198238</td>
#     </tr>
#     <tr>
#       <th id="T_3a309_level0_row1" class="row_heading level0 row1" >981</th>
#       <td id="T_3a309_row1_col0" class="data row1 col0" >6801613</td>
#       <td id="T_3a309_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_3a309_row1_col2" class="data row1 col2" >4.285714</td>
#       <td id="T_3a309_row1_col3" class="data row1 col3" >One Piece, Volume 37: Tom (One Piece, #37)</td>
#       <td id="T_3a309_row1_col4" class="data row1 col4" >194</td>
#       <td id="T_3a309_row1_col5" class="data row1 col5" ><a target= "_blank" href="https://www.goodreads.com/book/show/6801613-one-piece-volume-37">Goodreads</a></td>
#       <td id="T_3a309_row1_col6" class="data row1 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_3a309_row1_col7" class="data row1 col7" >one piece volume 37 tom one piece 37</td>
#       <td id="T_3a309_row1_col8" class="data row1 col8" >0.252577</td>
#       <td id="T_3a309_row1_col9" class="data row1 col9" >1.082474</td>
#     </tr>
#     <tr>
#       <th id="T_3a309_level0_row2" class="row_heading level0 row2" >975</th>
#       <td id="T_3a309_row2_col0" class="data row2 col0" >6801575</td>
#       <td id="T_3a309_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_3a309_row2_col2" class="data row2 col2" >3.625000</td>
#       <td id="T_3a309_row2_col3" class="data row2 col3" >One Piece, Volume 42: Pirates vs. CP9 (One Piece, #42)</td>
#       <td id="T_3a309_row2_col4" class="data row2 col4" >218</td>
#       <td id="T_3a309_row2_col5" class="data row2 col5" ><a target= "_blank" href="https://www.goodreads.com/book/show/6801575-one-piece-volume-42">Goodreads</a></td>
#       <td id="T_3a309_row2_col6" class="data row2 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_3a309_row2_col7" class="data row2 col7" >one piece volume 42 pirates vs cp9 one piece 42</td>
#       <td id="T_3a309_row2_col8" class="data row2 col8" >0.293578</td>
#       <td id="T_3a309_row2_col9" class="data row2 col9" >1.064220</td>
#     </tr>
#     <tr>
#       <th id="T_3a309_level0_row3" class="row_heading level0 row3" >984</th>
#       <td id="T_3a309_row3_col0" class="data row3 col0" >6801643</td>
#       <td id="T_3a309_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_3a309_row3_col2" class="data row3 col2" >4.428571</td>
#       <td id="T_3a309_row3_col3" class="data row3 col3" >One Piece, Volume 30: Capriccio (One Piece, #30)</td>
#       <td id="T_3a309_row3_col4" class="data row3 col4" >208</td>
#       <td id="T_3a309_row3_col5" class="data row3 col5" ><a target= "_blank" href="https://www.goodreads.com/book/show/6801643-one-piece-volume-30">Goodreads</a></td>
#       <td id="T_3a309_row3_col6" class="data row3 col6" ><img src="https://images.gr-assets.com/books/1336429417m/6801643.jpg" width=50></img></td>
#       <td id="T_3a309_row3_col7" class="data row3 col7" >one piece volume 30 capriccio one piece 30</td>
#       <td id="T_3a309_row3_col8" class="data row3 col8" >0.235577</td>
#       <td id="T_3a309_row3_col9" class="data row3 col9" >1.043269</td>
#     </tr>
#     <tr>
#       <th id="T_3a309_level0_row4" class="row_heading level0 row4" >992</th>
#       <td id="T_3a309_row4_col0" class="data row4 col0" >6891484</td>
#       <td id="T_3a309_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_3a309_row4_col2" class="data row4 col2" >4.375000</td>
#       <td id="T_3a309_row4_col3" class="data row4 col3" >One Piece, Volume 25: The 100 Million Berry Man (One Piece, #25)</td>
#       <td id="T_3a309_row4_col4" class="data row4 col4" >288</td>
#       <td id="T_3a309_row4_col5" class="data row4 col5" ><a target= "_blank" href="https://www.goodreads.com/book/show/6891484-one-piece-volume-25">Goodreads</a></td>
#       <td id="T_3a309_row4_col6" class="data row4 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_3a309_row4_col7" class="data row4 col7" >one piece volume 25 the 100 million berry man one piece 25</td>
#       <td id="T_3a309_row4_col8" class="data row4 col8" >0.222222</td>
#       <td id="T_3a309_row4_col9" class="data row4 col9" >0.972222</td>
#     </tr>
#   </tbody>
# </table>
